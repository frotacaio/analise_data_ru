# %%
import pandas as pd
from datetime import datetime

from matplotlib import pyplot as plt

from analise_data_ru import ROOT_PATH
from analise_data_ru.plot import get_almoco_and_janta_plot

# %%
df_ru = pd.read_csv(ROOT_PATH / 'data' / 'processed' / 'final_base.csv')
df_ru
# Out:
#            Data   ano  mes  dia_semana  dia  Qt_almoco  Qt_jantar
# 0    2016-01-04  2016    1           0    4        364        294
# 1    2016-01-05  2016    1           1    5        489        363
# 2    2016-01-06  2016    1           2    6        522        401
# 3    2016-01-07  2016    1           3    7        514        349
# 4    2016-01-08  2016    1           4    8        409        218
# ..          ...   ...  ...         ...  ...        ...        ...
# 984  2020-03-24  2020    3           1   24         10          9
# 985  2020-03-26  2020    3           3   26         11         13
# 986  2020-03-27  2020    3           4   27         15         14
# 987  2020-03-30  2020    3           0   30         13         12
# 988  2020-03-31  2020    3           1   31         14          9
#
# [989 rows x 7 columns]

# %%
df_ru[['Qt_almoco', 'Qt_jantar']]
# Out:
#      Qt_almoco  Qt_jantar
# 0          364        294
# 1          489        363
# 2          522        401
# 3          514        349
# 4          409        218
# ..         ...        ...
# 984         10          9
# 985         11         13
# 986         15         14
# 987         13         12
# 988         14          9
#
# [989 rows x 2 columns]

# %%
print(f'Date: {df_ru.loc[0, "Data"]}')
datetime.strptime(df_ru.loc[0, "Data"], "%Y-%m-%d")
# Out:
# Date: 2016-01-04
# datetime.datetime(2016, 1, 4, 0, 0)

# %%
date_field = df_ru['Data'].apply(lambda x: datetime.strptime(x, "%Y-%m-%d"))
date_field
# Out:
# 0     2016-01-04
# 1     2016-01-05
# 2     2016-01-06
# 3     2016-01-07
# 4     2016-01-08
#          ...
# 984   2020-03-24
# 985   2020-03-26
# 986   2020-03-27
# 987   2020-03-30
# 988   2020-03-31
# Name: Data, Length: 989, dtype: datetime64[ns]

# %%
get_almoco_and_janta_plot(df_ru)
# Out:
# /home/aizen/dev/comp-eng/analise_data_ru/analise_data_ru/plot.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[index].set_xticklabels(ax[index].get_xticklabels(), rotation=45)
# /home/aizen/dev/comp-eng/analise_data_ru/analise_data_ru/plot.py:39: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(plots, labels=labels, loc='upper right',)

# %%
train_df = df_ru.iloc[:-90]
test_df_ = df_ru.iloc[-90:]

test_df = test_df_.iloc[:-10]

# %%
train_df
# Out:
#            Data   ano  mes  dia_semana  dia  Qt_almoco  Qt_jantar
# 0    2016-01-04  2016    1           0    4        364        294
# 1    2016-01-05  2016    1           1    5        489        363
# 2    2016-01-06  2016    1           2    6        522        401
# 3    2016-01-07  2016    1           3    7        514        349
# 4    2016-01-08  2016    1           4    8        409        218
# ..          ...   ...  ...         ...  ...        ...        ...
# 894  2019-10-29  2019   10           1   29        836        550
# 895  2019-10-30  2019   10           2   30        866        567
# 896  2019-10-31  2019   10           3   31        782        539
# 897  2019-11-01  2019   11           4    1        640        333
# 898  2019-11-04  2019   11           0    4        798        533
#
# [899 rows x 7 columns]

# %%
test_df.tail(10)
# Out:
#            Data   ano  mes  dia_semana  dia  Qt_almoco  Qt_jantar
# 969  2020-03-02  2020    3           0    2        847        614
# 970  2020-03-03  2020    3           1    3       1033        687
# 971  2020-03-04  2020    3           2    4        830        608
# 972  2020-03-05  2020    3           3    5        944        691
# 973  2020-03-06  2020    3           4    6        823        353
# 974  2020-03-09  2020    3           0    9        843        639
# 975  2020-03-10  2020    3           1   10       1001        626
# 976  2020-03-11  2020    3           2   11       1002        611
# 977  2020-03-12  2020    3           3   12        953        549
# 978  2020-03-13  2020    3           4   13        795        410

# %%
get_almoco_and_janta_plot(train_df)
# Out:
# /home/aizen/dev/comp-eng/analise_data_ru/analise_data_ru/plot.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[index].set_xticklabels(ax[index].get_xticklabels(), rotation=45)
# /home/aizen/dev/comp-eng/analise_data_ru/analise_data_ru/plot.py:39: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(plots, labels=labels, loc='upper right',)

# %%
get_almoco_and_janta_plot(test_df)
# Out:
# /home/aizen/dev/comp-eng/analise_data_ru/analise_data_ru/plot.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[index].set_xticklabels(ax[index].get_xticklabels(), rotation=45)
# /home/aizen/dev/comp-eng/analise_data_ru/analise_data_ru/plot.py:39: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(plots, labels=labels, loc='upper right',)

# %%
train_df.to_csv(ROOT_PATH / 'data' / 'processed' / 'train_data.csv', index=False)
test_df.to_csv(ROOT_PATH / 'data' / 'processed' / 'test_data.csv', index=False)
