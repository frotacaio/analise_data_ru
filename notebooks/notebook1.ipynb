# %%
import pandas as pd

from analise_data_ru import ROOT_PATH

# %%
pd.read_csv(ROOT_PATH / 'data' / 'raw' / 'data_ru.csv')
# Out:
#        date;"lunch";"dinner"
# 0     2016-01-04;"364";"294"
# 1     2016-01-05;"489";"363"
# 2     2016-01-06;"522";"401"
# 3     2016-01-07;"514";"349"
# 4     2016-01-08;"409";"218"
# ...                      ...
# 1090      2020-03-25;"0";"0"
# 1091    2020-03-26;"11";"13"
# 1092    2020-03-27;"15";"14"
# 1093    2020-03-30;"13";"12"
# 1094     2020-03-31;"14";"9"
#
# [1095 rows x 1 columns]

# %%
pd.read_excel(ROOT_PATH / 'data' / 'raw' / 'Quantitativo RU_Sobral .xlsx')
# Out:
#        ALMOÇO SOBRAL Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                NaN        NaN         NaN         NaN         NaN
# 1            JANEIRO        NaN         NaN         NaN         NaN
# 2          CATEGORIA       DATA         NaN         NaN         NaN
# 3                NaN          2         3.0         4.0         5.0
# 4          ESTUDANTE          0         0.0         0.0         0.0
# ..               ...        ...         ...         ...         ...
# 175       AUTORIZADO          5         5.0       481.0         5.0
# 176        VISITANTE          0         0.0         0.0         0.0
# 177  EVENTO GRATUITO          0         0.0         0.0         0.0
# 178   EVENTO PAGANTE          0         0.0         0.0         0.0
# 179            TOTAL        592       655.0       668.0       601.0
#
#      Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0           NaN         NaN         NaN         NaN         NaN  ...
# ...
